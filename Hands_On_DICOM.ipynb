# %% [markdown]
# <a href="https://colab.research.google.com/github/straus91/hands_on_dicom/blob/main/Hands_On_DICOM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #**Introdução:**

# %% [markdown]
# ![python_icon.png](data:image/png;base64,...)
# <br><br>
# [https://www.python.org/](https://www.python.org/)
#
# ## **Python** é uma linguagem de programação que tem como uma de suas principais características a "legibilidade", ou seja é uma linguagem que tende a ser mais legível e clara.
# ## É considerada a linguagem de programação mais popular do mundo e muito utilziada para ensinar programação básica.
#
#
# <br> <br>
# <br> <br>
#
# ---

# %% [markdown]
# ![colab_icon.png](data:image/png;base64,...)
# <br><br>
# [https://colab.research.google.com/](https://colab.research.google.com/)
#
# ## **Colab** ou "Colaboratory" é uma plataforma da Google que permite escrever e exectura Python no próprio navegador
#
#
# <br><br>
#
# ---

# %% [markdown]
# ![jupyter_icon.png](data:image/png;base64,...)
# <br><br>
# [https://jupyter.org/](https://jupyter.org/)
#
#
#
# ## No Colab é possível criar **notebooks** através do **Jupyter Notebook App**, que te permitem facilmente misturar texto, imagens e código em um único lugar.
# ## Além esses **notebooks** são muito úteis pois nos permitem escrever e executar o código em pequenos passos facilitando muitos experimentos
#
#
#
# <br><br>
# ---

# %% [markdown]
# # **Como um notebook funciona?**

# %% [markdown]
# ## Cada notebook é composto de "células" onde podemos escrever texto simples ou código, no nosso caso código em python.
# <br><br>

# %% [markdown]
# ## **Células de Texto**:
# ![cell_texto.JPG](data:image/jpeg;base64,...)
#
# <br><br>
# ## São células onde voce pode escrever texto livremente. Esse texto não sera interpretado como código e é útil para explicar algo parra o leitor do notebook ou deixar alguma idéia documentada.
# ## **A caixa logo abaixo representa uma célula de texto**

# %% [markdown]
# ## **Células de Código**:
# <br><br>
# ![cell_codigo.JPG](data:image/jpeg;base64,...)
#
# ##São células utilizadas tanto para escrever código quanto para executar o código escrito.
# ## De uma forma geral todo o texto incluido em uma célula desse tipo vai ser interpretada como código.
# ## As células de código podem ser identificadas ou por dois colchetes [ ] ou por um  botão de "play" ao lado. Esse botão é utilizada para executar o código.
# ![cell_codigo_c.JPG](data:image/jpeg;base64,...)
# ![cell_codigo_r.JPG](data:image/jpeg;base64,...)
# <br><br>
# ## A célula abaixo representa uma célula de código

# %%
# Out:
#   File "<ipython-input-8-23ba85441436>", line 1
#     vou escrever um texto aqui
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##Células de código serão nossa principal ferramenta de trabalho neste curso.
# ##Uma vez que o código estiver pronto é só clicar no botão play ou apertar **shift + enter** para executar o código e obter o resultado do código, que será exibido logo abaixo da mesma célula

# %%
1 + 1

# %%
print("Hello World")
# Out:
# Hello World

# %%
X = 2
Y = 3
Z = X + Y
# Out:
# 5
# 2 3
# 2 + 3 = 5

# %%
print(X+Y)
print(X,Y)
# Out:
# 5
# 2 3

# %%
print(X, "+", Y, "=", Z)
# Out:
# 2 + 3 = 5

# %% [markdown]
# # **Breve Intro de Python**

# %% [markdown]
# ## **Variaveis**

# %%
#Variaveis
#Podemos pensar em variaveis como uma caixa onde podemos armazenar informacoes.
#A informacao pode ser de varios tipos, como por exemplo numeros ou texto.
#Neste primeiro exemplo vamos criar uma variavel e armazenar um numero nela e depois um texto nela
#Toda a variavel tem que ter um "nome" para que possamos identifica-la, neste primeiro exemplo vamos criar uma variavel 
#chamada variavel_1 e vamos colocar um valor inteiro nela

# %%
variavel_1

# %%
variavel_1 = 2938473

# %%
#para checar qual o valor da variavel basta digitar o seu nome e rodar a celuar, que o computador te responde com o seu valor
variavel_1
# Out:
# 2938473

# %%
#e possivel mudar o variavel livremente e atribuir novos valores a mesma variavel da mesma forma. 
#A variavel sempre contera o ultimo valor inserido nela
variavel_1
# Out:
# 1234

# %%
variavel_1 = 1234

# %%
variavel_1
# Out:
# 1234

# %%
#Para indicar para o computador que voce deseja armazenar um texto em uma variavel e preciso colocar o texto entre aspas. Chamamos isso de string

# %%
variavel_1 = "escreva aqui um texto"

# %%
variavel_1
# Out:
# 'escreva aqui um texto'

# %%
#Variaveis podem armazenar muito mais do que apenas numeros e texto. Nesse curso iremos usar as variaveis para armazenar por exemplo informacoes dos arquivos dicom

# %% [markdown]
# #**DICOM**

# %% [markdown]
# #**Trabalhando com Python e DICOM**

# %% [markdown]
# ### Primeiro vamos instalar e importar um **biblioteca** chamada **pydicom**.
# ### **Bibliotecas** nada mais são do que coleções de códigos já escritas e que tem uma função específica.
# ###Existem diversas bibliotecas disponíveis para Python e nós vamos usar uma delas chamada **pydicom**.
# ### Essa biblioteca tem muitos pedaços de código que tornam manipular um arquivo dicom muito mais fácil. Por isso nós vamos **instalar** e depois **importar** essa biblioteca.

# %%
#Instalando o pydicom
# !pip install pydicom
# Out:
# ...
#      |████████████████████████████████| 2.0 MB 5.0 MB/s
# ...

# %%
import pydicom

# %% [markdown]
# ### O que podemos fazer com o pydicom?
#
# *   Explorar um arquivo dicom
# *   Modificar um arquivo dicom

# %% [markdown]
# ### Explorando um arquivo dicom

# %%
pydicom
# Out:
# <module 'pydicom' from '/usr/local/lib/python3.7/dist-packages/pydicom/__init__.py'>
